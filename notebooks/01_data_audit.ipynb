# %% [markdown]
# # 01 - Data audit
#
# Run after `make build` (or `scripts/02_build_dataset.py`). Loads the cleaned CSV and previews rows. Requirement IDs: DATA-001, EDA-001-003.

# %%
from adult_income_ml.data import load_clean
from adult_income_ml.utils import load_config
df = load_clean(load_config())
df.head()

# %% [markdown]
# # 03 - Model experiments
#
# Run after `make tune`. Inspect tuning JSON and compare CV scores across model families.

# %%
import json
from adult_income_ml.utils import get_paths
p = get_paths()['cv_results'] / 'tuning_results.json'
print(json.dumps(json.loads(p.read_text()), indent=2) if p.exists() else 'Run scripts/05_tune_models.py')

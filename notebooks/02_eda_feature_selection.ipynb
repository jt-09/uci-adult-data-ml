# %% [markdown]
# # 02 - EDA and feature selection
#
# Run after `make eda`. Explores distributions and feature roles. See `reports/figures/` for generated plots.

# %%
from adult_income_ml.data import load_clean
from adult_income_ml.features import get_feature_columns
from adult_income_ml.utils import load_config
cfg = load_config()
df = load_clean(cfg)
df[get_feature_columns(cfg)['numeric']].describe()

# %% [markdown]
# # 04 - Interpretability and fairness
#
# Run after `make fairness`. Loads permutation importance tables and subgroup metrics from `reports/tables/`.

# %%
import pandas as pd
from adult_income_ml.utils import get_paths
p = get_paths()['tables'] / 'table_16_representative_errors.csv'
display(pd.read_csv(p)) if p.exists() else print('Run scripts/07-08')

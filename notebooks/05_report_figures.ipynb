# %% [markdown]
# # 05 - Report figures
#
# Run after `make report`. Quick check that figures in `reports/figures/` match the report narrative (RPT-001).

# %%
from adult_income_ml.utils import get_paths
figs = sorted(get_paths()['figures'].glob('*.png'))
print(f'{len(figs)} figures')
for f in figs:
    print(f.name)
